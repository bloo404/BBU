# %%
# Imports

from random import randint, random, randrange, uniform
from operator import add
from math import cos, pi
from numpy import random
import numpy as np

# %%
# Genetic algorithm with weighted n-queen problem
# 1. Initialization
def individual_matrix(chromosome_length):
    return np.random.permutation(chromosome_length)

# chromosome_length = how many queens generated
# creates a vector that the sum of represents the position on the column

def initialize_population(population_size, chromosome_length):
    return [individual_matrix(chromosome_length) for x in range(population_size)]

N = 8
population_size = N*1000 # generate a big sample because the if the sample is too small it's game over with thhe generations
chromosome_length = N
population = initialize_population(population_size, chromosome_length)
print(population)
# Out:
# [array([0, 7, 2, 5, 3, 1, 6, 4]), array([4, 3, 0, 1, 6, 5, 2, 7]), array([3, 6, 1, 2, 4, 0, 7, 5]), array([4, 1, 7, 3, 6, 0, 2, 5]), array([3, 6, 1, 5, 0, 2, 7, 4]), array([2, 4, 1, 3, 5, 7, 6, 0]), array([7, 2, 6, 4, 1, 5, 0, 3]), array([1, 4, 2, 5, 0, 7, 3, 6]), array([7, 5, 6, 0, 1, 4, 2, 3]), array([1, 3, 5, 6, 7, 0, 4, 2]), array([3, 1, 4, 7, 5, 0, 6, 2]), array([5, 0, 3, 7, 2, 4, 6, 1]), array([6, 3, 7, 5, 1, 2, 0, 4]), array([1, 7, 3, 5, 4, 2, 6, 0]), array([3, 2, 1, 5, 4, 0, 7, 6]), array([6, 4, 2, 5, 7, 3, 1, 0]), array([6, 0, 5, 2, 7, 1, 3, 4]), array([7, 1, 4, 3, 0, 2, 5, 6]), array([3, 0, 4, 1, 5, 6, 7, 2]), array([1, 5, 2, 3, 6, 4, 0, 7]), array([6, 4, 3, 2, 5, 1, 7, 0]), array([5, 1, 3, 6, 2, 7, 4, 0]), array([3, 6, 7, 2, 4, 0, 5, 1]), array([4, 2, 6, 5, 3, 1, 0, 7]), array([3, 5, 4, 0, 7, 1, 6, 2]), array([4, 0, 1, 6, 5, 3, 7, 2]), array([1, 7, 0, 5, 4, 2, 6, 3]), array([1, 0, 2, 4, 5, 3, 6, 7]), array([1, 2, 4, 6, 3, 0, 7, 5]), array([4, 3, 5, 6, 0, 2, 1, 7]), array([7, 3, 5, 4, 0, 2, 1, 6]), array([5, 3, 0, 7, 6, 2, 4, 1]), array([5, 7, 1, 2, 6, 0, 3, 4]), array([3, 1, 5, 0, 7, 2, 6, 4]), array([4, 5, 1, 2, 7, 6, 3, 0]), array([4, 3, 2, 6, 7, 5, 0, 1]), array([1, 4, 5, 0, 6, 3, 2, 7]), array([5, 3, 2, 1, 6, 0, 4, 7]), array([5, 2, 3, 0, 1, 6, 4, 7]), array([7, 4, 0, 3, 6, 1, 2, 5]), array([6, 5, 1, 0, 2, 4, 3, 7]), array([4, 1, 3, 7, 0, 5, 2, 6]), array([5, 4, 6, 3, 0, 1, 7, 2]), array([7, 1, 3, 2, 4, 5, 0, 6]), array([1, 2, 4, 5, 3, 6, 7, 0]), array([6, 0, 2, 3, 5, 4, 1, 7]), array([2, 6, 5, 3, 1, 0, 7, 4]), array([7, 5, 6, 3, 4, 2, 1, 0]), array([4, 5, 3, 2, 6, 0, 7, 1]), array([6, 1, 4, 5, 3, 0, 7, 2]), array([0, 3, 4, 5, 2, 1, 6, 7]), array([4, 3, 0, 2, 1, 6, 7, 5]), array([3, 2, 0, 6, 7, 1, 5, 4]), array([3, 6, 5, 0, 7, 4, 2, 1]), array([2, 7, 6, 0, 4, 5, 1, 3]), array([3, 2, 7, 6, 5, 1, 4, 0]), array([3, 7, 6, 5, 2, 1, 0, 4]), array([3, 6, 4, 0, 2, 5, 1, 7]), array([2, 1, 5, 7, 0, 4, 6, 3]), array([2, 4, 6, 3, 0, 7, 1, 5]), array([4, 1, 3, 7, 5, 0, 2, 6]), array([7, 3, 2, 5, 6, 1, 4, 0]), array([2, 4, 3, 0, 5, 7, 1, 6]), array([3, 7, 6, 2, 4, 5, 0, 1]), array([2, 5, 1, 0, 3, 7, 4, 6]), array([2, 7, 1, 5, 0, 3, 6, 4]), array([6, 1, 3, 2, 7, 5, 0, 4]), array([3, 7, 1, 5, 6, 0, 2, 4]), array([2, 5, 1, 4, 6, 7, 0, 3]), array([5, 1, 0, 3, 7, 6, 4, 2]), array([3, 2, 5, 6, 1, 7, 0, 4]), array([3, 0, 4, 5, 2, 7, 6, 1]), array([1, 6, 4, 5, 0, 2, 3, 7]), array([5, 0, 6, 7, 3, 4, 1, 2]), array([0, 7, 1, 2, 6, 4, 3, 5]), array([7, 4, 3, 6, 5, 2, 1, 0]), array([5, 3, 6, 4, 2, 1, 0, 7]), array([7, 3, 4, 5, 6, 1, 0, 2]), array([2, 3, 4, 1, 6, 7, 5, 0]), array([0, 5, 6, 4, 1, 2, 3, 7]), array([3, 5, 2, 6, 0, 4, 7, 1]), array([1, 4, 7, 5, 6, 2, 0, 3]), array([1, 6, 3, 0, 7, 4, 2, 5]), array([4, 3, 1, 0, 7, 2, 5, 6]), array([2, 7, 3, 4, 1, 0, 5, 6]), array([0, 2, 3, 5, 6, 7, 1, 4]), array([1, 2, 6, 7, 0, 5, 3, 4]), array([0, 6, 2, 1, 5, 7, 4, 3]), array([4, 0, 2, 3, 5, 7, 1, 6]), array([2, 0, 6, 7, 5, 3, 4, 1]), array([5, 1, 4, 3, 7, 2, 0, 6]), array([7, 2, 5, 6, 3, 1, 4, 0]), array([1, 6, 7, 5, 3, 4, 2, 0]), array([1, 4, 6, 3, 5, 7, 0, 2]), array([7, 5, 1, 6, 4, 2, 3, 0]), array([6, 5, 1, 7, 4, 0, 2, 3]), array([5, 2, 4, 7, 6, 0, 1, 3]), array([3, 0, 7, 2, 4, 5, 1, 6]), array([0, 2, 4, 3, 6, 7, 5, 1]), array([7, 6, 2, 0, 4, 3, 5, 1]), array([2, 3, 6, 1, 5, 7, 0, 4]), array([0, 4, 1, 5, 6, 7, 2, 3]), array([5, 1, 7, 3, 4, 0, 6, 2]), array([6, 4, 3, 5, 2, 7, 1, 0]), array([7, 6, 4, 0, 3, 2, 5, 1]), array([2, 5, 3, 0, 1, 7, 4, 6]), array([4, 3, 5, 7, 0, 2, 1, 6]), array([5, 0, 2, 4, 7, 6, 3, 1]), array([6, 2, 7, 1, 3, 4, 5, 0]), array([3, 4, 0, 7, 6, 2, 5, 1]), array([3, 4, 0, 1, 7, 2, 5, 6]), array([2, 6, 4, 5, 1, 7, 0, 3]), array([4, 3, 2, 5, 0, 1, 7, 6]), array([2, 1, 6, 3, 5, 4, 0, 7]), array([6, 2, 5, 4, 7, 0, 1, 3]), array([3, 7, 6, 5, 0, 1, 4, 2]), array([5, 3, 7, 2, 4, 1, 6, 0]), array([3, 0, 1, 6, 4, 5, 2, 7]), array([3, 6, 1, 0, 4, 7, 5, 2]), array([1, 7, 0, 2, 4, 6, 5, 3]), array([1, 2, 6, 3, 5, 4, 7, 0]), array( ...

# %%
# 2. Fitness Evaluation (validare)

# in case it s needed to have unique solutions that do not repeat
def get_unique_arrays(arrays):
    unique_arrays = set()
    for array in arrays:
        unique_arrays.add(tuple(array))
    return [list(array) for array in unique_arrays]

# computes weight for each individual
def compute_weight(individual, weights, length):
    sum_weight = 0
    for i in range(0,length):
        sum_weight = sum_weight + weights[i][individual[i]]
        # print(weights[i][individual[i]])
    return sum_weight

# computes all weights for the whole population
def all_weights_for_population(population, weights, length):
    #for individual in population:
    #    print("------------------")
    #    print(individual)
    #    print(compute_weight(individual, weights, length))   
    return [compute_weight(individual, weights, length) for individual in population]

# computes if the queens are attacking
def function_fitness(individual, length):
    t1 = 0
    t2 = 0
    f1 = []
    f2 = []
    for i in range(0,length):
        f1.append(individual[i] - i)
        f2.append((1 + length) - individual[i] - i)
    f1.sort()
    f2.sort()
    for i in range(1,length):
        if f1[i] == f1[i-1]:
            t1 = t1 + 1
        if f2[i] == f2[i-1]:
            t2 = t2 + 1
    fitness_value = t1 + t2
    return fitness_value

# Evaluates fitness (computes fitness scores with weights inside)
def evaluate_fitness(population, weights, length):
    fitness_scores = []
    for individual in population:
        if function_fitness(individual, length) == 0:
            fitness_scores.append(compute_weight(individual, weights, length)) # adds the weights to the fitness scores list
        else:
            fitness_scores.append(compute_weight(individual,weights,length) - len(individual) * function_fitness(individual,length))
    return fitness_scores

# to generate the matrix
def randomize_matrix(rows, cols, min_val, max_val):
    matrix = [[random.randint(min_val, max_val) for _ in range(cols)] for _ in range(rows)]
    return matrix

rows = 8
cols = 8
min_val = 1
max_val = 10
weights = randomize_matrix(rows, cols, min_val, max_val)
print(weights)

# fitness scores have weights now and the population is renewed
# the villages with the queens that attack each other died
fitness_scores = evaluate_fitness(population, weights, N)

# population = get_unique_arrays(population)

# Compute all weights for them (Initially was thought for this to be separate)
all_weights = all_weights_for_population(population, weights, N)

print("---------------------------")
print("FITNESS SCORES FOR EVERY INDIVIDUAL IN POPULATION: \n =0 means no queens on diagonal, \n >0 means more queens on a diagonal")
print(fitness_scores)
print("---------------------------")
print("Sum of weights for every individual in the population: ")
print("---------------")
print("All weights:")
print(all_weights)
print("---------------------------")
# Out:
# [[6, 7, 3, 1, 5, 7, 3, 8], [3, 5, 7, 6, 6, 8, 1, 6], [6, 9, 5, 8, 6, 2, 5, 2], [1, 3, 5, 8, 1, 9, 2, 6], [8, 9, 3, 3, 6, 9, 6, 4], [7, 6, 4, 6, 5, 1, 2, 2], [1, 7, 8, 1, 3, 2, 8, 8], [2, 5, 5, 5, 2, 2, 1, 6]]
# ---------------------------
# FITNESS SCORES FOR EVERY INDIVIDUAL IN POPULATION:
#  =0 means no queens on diagonal,
#  >0 means more queens on a diagonal
# [21, -7, 15, 35, 18, 23, 13, 23, 17, 4, 23, 29, 4, 10, 0, 18, -14, 10, 13, 14, 7, 16, -3, 18, 7, 15, 27, 5, 26, 0, -3, 11, 11, -37, 12, -11, 26, -13, -5, 26, -12, 2, 29, 3, 4, 6, 16, -8, 20, 22, 2, 11, -10, -13, 2, -8, 1, -6, 10, 25, 25, 5, 13, -10, -2, 27, -3, 16, 3, 8, -6, -3, 18, -7, 16, -10, 19, 7, -10, 0, 18, 24, 28, -16, 5, 23, 5, 2, 16, 0, 12, 1, -11, 19, 8, 12, 11, 2, 10, 2, 7, 11, -8, 8, -10, 11, -1, 12, -5, 20, -13, 4, 0, 2, -4, 19, 18, -12, 3, 7, 19, 20, 14, -24, 36, 7, 13, -16, 15, 13, 24, -7, -4, 5, 18, 0, 32, 23, 6, -3, -1, 10, -1, 12, 13, 17, -15, -1, -9, 28, -12, 7, 15, 10, 14, 6, 1, 12, 16, 8, 14, 5, -9, -3, 5, 1, 3, 16, -2, 4, 2, -10, 4, -5, -11, 0, 4, 7, 13, 14, -6, 13, 4, 5, 15, 10, 8, 3, -5, -11, -24, 10, -13, -2, 22, -3, 2, 18, 32, -18, 9, 6, -7, 7, 9, 3, 31, -4, 5, 30, 7, -6, -3, 10, -5, 0, 28, 4, 19, -8, 8, -2, 19, 19, 9, 13, 3, 0, -3, -6, 19, 15, 33, 8, -5, 7, 7, 15, 23, -14, 9, 25, -6, -13, 12, -29, 12, 16, 13, 20, 2, 19, 10, 13, -7, 17, -6, -2, 18, 12, 9, 0, 6, 0, -14, -1, 27, 18, 29, 8, 11, 22, 10, 9, 9, 9, -5, 16, -5, 4, 10, 13, 3, 7, -1, 14, 6, 26, 12, -1, 9, 8, -28, -9, 12, 7, 5, -12, 13, -12, 14, -3, 8, 1, 6, -13, 20, -10, 27, 2, 19, -6, -14, 14, -18, 10, 3, 10, 30, -3, 4, 14, -6, -5, -9, 3, -10, -14, 21, 8, 9, -17, 11, 23, 9, -1, 4, -12, -22, 1, 42, -5, 8, 22, -4, 23, 11, 3, 11, -8, 4, 16, 8, 0, -13, 4, -2, 0, -4, 21, 8, 14, 2, 29, -12, 11, 24, 5, 7, 9, 0, -13, 5, 21, 8, 5, 8, 4, 27, 11, 10, 24, 0, 3, 0, 18, 26, 21, -2, 22, -16, 0, -3, -4, 18, 18, -18, 40, 8, 20, 9, 22, -18, -1, -5, -5, 0, -6, 10, 2, 1, -9, 7, 17, 25, 0, 7, 22, -9, 9, -17, 14, 11, -11, 8, 9, 20, -8, 0, 11, 9, 6, -1, -2, -3, 10, 6, 12, 4, -1, 25, 21, 7, 12, -8, 11, 31, -22, -6, 13, 17, 11, 7, -6, -23, -1, 5, -9, -13, 4, -1, 18, 4, 0, 21, 26, -18, 7, -2, 17, 16, -5, -1, 3, 5, 8, 9, 2, 7, 15, 15, 12, 21, 17, 4, 16, 6, 3, 9, 5, 10, -13, 29, 11, 9, 14, 4, -4, 6, -6, 8, 3, -6, 13, 38, 4, 25, 2, 13, 24, 13, 13, -8, 15, -7, 19, 3, 21, -11, 17, 7, 24, 13, -3, 13, 20, -19, 20, 13, 22, -7, 13, 9, -18, 16, 5, 17, 15, 11, 45, 22, 11, -7, 22, 10, -3, 9, 2, -7, 9, 14, 13, 5, -2, 20, 3, 35, 8, -6, 2, 10, 28, -1, 21, 7, 7, 13, 24, 13, 10, -10, -2, 16, 1, 10, -1, 9, 19, 17, 6, 12, 26, -1, -4, 17, -8, -4, 5, 17, 7, 12, 17, 27, 2, 13, -10, -38, 25, -9, 4, 1, -12, 14, -11, 14, -2, -9, 18, 8, 41, -6, -6, -13, -25, 0, -4, -7, 8, -6, 14, -10, 6, 5, 22, 6, 12, 7, 8, 18, 14, 12, 17, -5, 3, -3, -18, 13, -14, -23, 6, 5, 1, 8, 2, 21, 17, 15, -6, -2, 10, -22, 27, 17, 2, -6, 28, 7, -13, 20, 12, 20, 3, 10, 31, 5, -2, 5, 23, 9, -34, -11, 13, 5, 1, 8, -2, 26, 11, 6, 9, 34, -4, -7, -2, -2, 10, -5, 14, 10, 37, 10, 15, 1, 7, -8, 9, 10, 9, 3, -14, 11, 3, -6, 16, -11, 11, -2, 16, -2, 5, 15, 3, 18, 2, 8, 9, -5, 20, 12, 5, 0, 23, 19, 27, 15, -9, -5, -18, 12, 10, 3, 12, -2, 19, 18, 7, 16, 5, -1, -9, 19, 3, 9, 4, 3, 1, 13, 5, 14, 20, 22, 21, 7, 8, -7, 5, -15, 2, 27, -14, 22, 9, 20, 9, 10, 21, -6, -15, 14, 5, -17, 14, -6, -4, -7, 35, 17, 9, -19, 0, 20, 4, -5, 7, -5, -28, 1, 3, -28, -10, 3, 37, 6, 8, 18, 16, 26, 10, 6, 17, 2, 2, 13, 11, 13, 4, 19, 4, 7, -1, -1, -2, 2, -11, -10, 13, 7, 22, 13, 6, -20, -7, 2, 2, -1, 0, 13, 10, -3, 12, -15, -7, 7, -5, -14, 8, -3, 23, -6, 18, 25, 10, -4, 14, -8, 3, -15, -7, 8, -12, 10, 13, 20, 1, -26, 22, 8, 21, 18, -4, 39, 3, 0, 3, -3, 3, 24, 24, 0, 4, -1, 8, 27, 9, 24, -1, 8, 18, 20, 11, -2, 19, 3, 5, 13, 16, 9, 23, 15, 2, 13, -14, -9, 13, 3, 12, -10, 35, 1, 5, 2, 20, 9, 22, -2, 0, 13, 2, 26, -9, -3, 10, 6, 4, 20, -12, -4, 17, 2, 31, -6, -25, 14, 32, -4, 7, -13, -2, -12, 31, 10, 16, 13, 23, -4, -10, -33, 9, -4, 11, 2, 7, 6, 0, 12, 19, -5, 4, -11, -5, -1, -9, 12, -1, -4, 2, -33, -4, -10, -8, 1, 2, 41, -10, 17, 2, -2, -4, 41, 8, 10, 23, 20, -24, 19, 11, -3, -4, 19, 19, 18, 14, 38, 21, -19, 16, 16, 12, 12, 6, -3, 8, 0, 11, 12, -6, 3, 2, -1, 13, -20, 2, 1, -25, 10, 11, 7, 7, 10, 2, -12, -7, -2, -10, 13, 1, 0, 15, 17, -13, -17, 8, 16, -3, -6, -1, -4, -13, -13, 8, 6, 5, 0, -1, 8, 1, 19, 4, 15, 2, -16, 3, -4, 4, -6, -7, 9, 18, 5, 27, 16, 14, 13, 2 ...
# ---------------------------
# Sum of weights for every individual in the population:
# ---------------
# All weights:
# [45, 41, 39, 43, 42, 47, 37, 39, 49, 36, 47, 45, 36, 50, 48, 42, 26, 42, 37, 46, 47, 32, 29, 42, 39, 47, 51, 45, 42, 40, 37, 43, 43, 27, 36, 29, 42, 43, 43, 50, 36, 42, 53, 35, 44, 46, 40, 48, 52, 46, 50, 43, 30, 27, 34, 32, 33, 26, 42, 41, 49, 45, 37, 30, 30, 51, 29, 48, 35, 40, 26, 37, 42, 41, 40, 46, 35, 47, 30, 40, 42, 40, 36, 32, 37, 47, 37, 34, 40, 40, 36, 33, 37, 43, 40, 52, 51, 26, 42, 34, 31, 51, 48, 40, 30, 35, 39, 28, 27, 36, 27, 36, 48, 42, 36, 43, 42, 36, 27, 39, 51, 44, 30, 32, 44, 39, 45, 32, 47, 45, 40, 25, 36, 37, 42, 32, 48, 39, 38, 29, 39, 34, 39, 36, 37, 41, 41, 31, 31, 44, 28, 39, 47, 42, 46, 38, 41, 36, 40, 32, 38, 29, 39, 53, 37, 25, 35, 40, 38, 36, 34, 30, 36, 35, 37, 40, 28, 39, 45, 46, 42, 53, 44, 45, 55, 42, 32, 35, 35, 29, 32, 34, 51, 30, 46, 37, 34, 42, 40, 22, 41, 38, 33, 39, 41, 27, 47, 36, 37, 46, 31, 34, 37, 34, 35, 40, 44, 44, 35, 32, 40, 30, 51, 35, 41, 37, 35, 40, 45, 34, 43, 47, 49, 32, 43, 39, 47, 31, 55, 42, 41, 41, 34, 27, 36, 43, 36, 40, 29, 44, 42, 51, 42, 53, 41, 41, 42, 30, 42, 36, 49, 40, 38, 40, 34, 31, 43, 42, 53, 40, 43, 46, 42, 49, 25, 33, 43, 40, 35, 36, 50, 45, 27, 31, 31, 38, 38, 42, 52, 31, 41, 48, 20, 31, 44, 39, 45, 36, 45, 28, 38, 37, 40, 33, 38, 35, 36, 38, 51, 34, 43, 34, 26, 38, 30, 42, 43, 42, 46, 29, 36, 38, 42, 43, 31, 43, 38, 18, 45, 40, 49, 23, 43, 39, 41, 39, 28, 28, 26, 33, 42, 35, 40, 46, 28, 39, 43, 35, 43, 24, 36, 40, 40, 32, 27, 44, 38, 32, 36, 37, 40, 46, 42, 37, 44, 43, 48, 37, 31, 41, 40, 27, 45, 37, 40, 37, 32, 36, 43, 43, 42, 48, 40, 43, 40, 50, 50, 45, 38, 38, 40, 40, 45, 36, 42, 50, 22, 56, 40, 44, 41, 46, 38, 39, 35, 35, 32, 34, 42, 34, 41, 31, 39, 41, 33, 40, 39, 46, 39, 33, 31, 38, 43, 29, 40, 33, 44, 40, 24, 43, 41, 46, 39, 38, 29, 42, 30, 44, 44, 39, 41, 45, 31, 44, 40, 35, 55, 26, 42, 37, 33, 51, 31, 34, 33, 23, 29, 31, 27, 44, 47, 42, 44, 32, 37, 34, 38, 31, 30, 49, 32, 43, 39, 43, 45, 40, 33, 42, 31, 39, 31, 36, 45, 41, 36, 48, 30, 43, 49, 29, 42, 35, 45, 35, 33, 46, 36, 44, 38, 26, 40, 35, 42, 37, 46, 36, 41, 34, 37, 32, 37, 37, 24, 39, 33, 51, 43, 45, 37, 33, 39, 40, 37, 37, 45, 44, 37, 44, 45, 46, 41, 45, 41, 30, 40, 37, 41, 39, 35, 45, 46, 51, 33, 46, 42, 29, 33, 42, 33, 41, 54, 45, 29, 30, 44, 35, 43, 40, 26, 42, 50, 44, 39, 45, 39, 39, 37, 40, 45, 42, 30, 38, 40, 33, 42, 31, 33, 43, 49, 46, 52, 50, 39, 44, 41, 32, 20, 37, 33, 39, 36, 49, 43, 34, 45, 30, 34, 49, 31, 36, 41, 28, 46, 45, 38, 38, 39, 42, 40, 41, 34, 34, 35, 31, 40, 36, 33, 32, 34, 46, 30, 30, 45, 46, 30, 44, 31, 40, 42, 38, 36, 49, 35, 35, 37, 30, 37, 26, 25, 38, 37, 33, 32, 34, 45, 41, 39, 42, 38, 42, 26, 51, 41, 34, 26, 44, 39, 27, 52, 44, 52, 35, 34, 47, 45, 38, 37, 47, 33, 30, 29, 45, 45, 41, 32, 46, 42, 35, 38, 33, 42, 36, 41, 30, 46, 42, 27, 46, 42, 45, 50, 39, 41, 47, 24, 41, 42, 41, 35, 26, 35, 43, 34, 48, 37, 43, 22, 40, 30, 45, 39, 35, 42, 34, 32, 33, 27, 52, 44, 37, 48, 31, 43, 43, 47, 31, 35, 30, 36, 34, 27, 44, 38, 43, 42, 39, 48, 37, 39, 31, 35, 35, 41, 36, 35, 49, 45, 29, 46, 44, 38, 45, 39, 40, 25, 45, 33, 42, 43, 42, 54, 33, 36, 41, 42, 45, 34, 33, 38, 45, 23, 46, 34, 36, 25, 51, 33, 33, 29, 32, 44, 36, 35, 47, 35, 20, 41, 35, 28, 30, 35, 45, 38, 40, 42, 48, 50, 34, 38, 33, 34, 42, 29, 43, 45, 44, 43, 44, 39, 39, 39, 38, 34, 37, 30, 45, 39, 38, 45, 46, 28, 33, 34, 34, 39, 32, 37, 42, 29, 36, 25, 41, 47, 35, 34, 48, 37, 55, 34, 34, 41, 42, 44, 46, 32, 35, 25, 33, 40, 28, 42, 37, 44, 33, 30, 38, 32, 37, 42, 44, 47, 35, 24, 35, 37, 43, 32, 40, 40, 28, 31, 40, 51, 41, 48, 31, 40, 42, 44, 35, 38, 43, 27, 37, 53, 48, 41, 47, 31, 34, 45, 26, 39, 37, 35, 52, 38, 43, 41, 37, 42, 44, 33, 46, 38, 40, 45, 34, 50, 23, 37, 42, 38, 36, 44, 36, 36, 33, 26, 31, 34, 23, 38, 48, 36, 31, 27, 38, 28, 47, 34, 48, 37, 47, 28, 30, 39, 41, 36, 35, 26, 23, 38, 32, 36, 35, 43, 44, 37, 35, 31, 39, 44, 23, 28, 42, 31, 28, 30, 32, 33, 34, 49, 46, 33, 26, 38, 28, 49, 32, 34, 39, 52, 24, 35, 35, 37, 44, 51, 51, 42, 46, 54, 45, 29, 40, 40, 36, 36, 38, 37, 40, 32, 43, 44, 26, 35, 34, 39, 37, ...
# ---------------------------

# %%
# 3. Selection

# this can be considered a tournament algorithm where we choose 
# the best two parents amongst all

def select_subsequence(population, tournament_size, fitness_scores, num_selections):
    selected = []
    pos = []
    
    for _ in range(int(num_selections)-1):
        tournament = random.choice(range(population_size), int(tournament_size))
        winner = None
        max_fitness = float('-inf')
        for participant in tournament:
            fitness = fitness_scores[participant]
            if fitness > max_fitness:
                max_fitness = fitness
                winner = participant
        pos.append(winner)
        selected.append(population[winner])
    return selected, pos

def select_parents(population, fitness_scores):
    # select two parents from the population based on the fitness - 
    # the better the fitness, the higher the chance to be selected
    # IN:  population, fitness_scores
    # OUT: selected_parents
    parents = []
    pos = []
    
    if fitness_scores[0] > fitness_scores[1]:
        parents.append(population[0])
        parents.append(population[1])
        maxi1 = fitness_scores[0]
        maxi2 = fitness_scores[1]
        pos.append(0)
        pos.append(1)
    else:
        parents.append(population[1])
        parents.append(population[0])
        maxi1 = fitness_scores[1]
        maxi2 = fitness_scores[0]        
        pos.append(1)
        pos.append(0)
        
    for i in range(2, len(fitness_scores)):
        if fitness_scores[i] >= maxi1:
            parents[1] = parents[0]
            maxi2 = maxi1
            parents[0] = population[i]
            maxi1 = fitness_scores[i]
            pos[1] = pos[0]
            pos[0] = i
        elif fitness_scores[i] > maxi2:
                parents[1] = population[i]
                maxi2 = fitness_scores[i]
                pos[1] = i
    return parents, pos

# parents, positions = select_parents(population, fitness_scores)
positions = []
parents, positions = select_subsequence(population, N*5, fitness_scores, N*5)
print(parents)
print(positions)
# Out:
# [array([0, 6, 2, 7, 5, 3, 1, 4]), array([2, 7, 3, 5, 0, 4, 6, 1]), array([6, 2, 3, 7, 0, 4, 1, 5]), array([4, 7, 0, 2, 5, 1, 6, 3]), array([6, 2, 3, 7, 0, 4, 1, 5]), array([4, 6, 0, 5, 3, 1, 2, 7]), array([3, 0, 2, 7, 5, 1, 6, 4]), array([4, 1, 3, 5, 7, 0, 2, 6]), array([5, 2, 1, 3, 0, 7, 4, 6]), array([5, 3, 1, 4, 2, 0, 6, 7]), array([7, 5, 3, 0, 4, 1, 6, 2]), array([7, 3, 0, 5, 1, 6, 4, 2]), array([0, 4, 1, 7, 5, 3, 2, 6]), array([5, 3, 0, 6, 4, 2, 1, 7]), array([7, 5, 1, 4, 0, 3, 6, 2]), array([6, 4, 1, 3, 5, 0, 2, 7]), array([7, 2, 0, 3, 5, 4, 6, 1]), array([7, 5, 2, 6, 1, 0, 4, 3]), array([6, 4, 2, 5, 1, 0, 7, 3]), array([6, 3, 1, 5, 2, 0, 7, 4]), array([0, 3, 6, 2, 5, 1, 4, 7]), array([7, 4, 3, 5, 6, 1, 0, 2]), array([4, 2, 0, 3, 1, 7, 5, 6]), array([2, 5, 0, 7, 1, 4, 6, 3]), array([2, 4, 1, 3, 0, 6, 7, 5]), array([4, 7, 1, 2, 5, 0, 6, 3]), array([5, 1, 4, 6, 0, 2, 7, 3]), array([3, 1, 4, 7, 0, 6, 2, 5]), array([4, 2, 1, 5, 6, 0, 3, 7]), array([2, 6, 1, 7, 4, 0, 3, 5]), array([0, 2, 4, 7, 1, 3, 5, 6]), array([6, 3, 1, 4, 7, 0, 2, 5]), array([6, 5, 0, 4, 1, 7, 2, 3]), array([2, 5, 3, 4, 7, 0, 6, 1]), array([5, 4, 6, 3, 0, 1, 7, 2]), array([3, 5, 7, 1, 4, 0, 2, 6]), array([5, 1, 6, 3, 0, 2, 7, 4]), array([0, 2, 4, 6, 1, 3, 7, 5]), array([3, 6, 4, 1, 5, 0, 2, 7])]
# [5835, 3304, 2778, 5045, 2778, 5693, 5099, 7642, 2528, 4096, 2072, 6932, 5972, 4064, 5221, 5426, 2168, 663, 1966, 4247, 3860, 1502, 4462, 2143, 6509, 3378, 7679, 7588, 6445, 6657, 4278, 3728, 3896, 1304, 42, 6169, 7452, 2084, 3903]

# %%
# 4. Crossover

def crossover(parents):
    point1 = randint(0,len(parents[0])/2-1)
    point2 = randint(len(parents[0])/2,len(parents[0])-1)
    parent1 = parents[0]
    parent2 = parents[1]
    parent1_chromosomes = parent1[point1:point2]
    
    child = []
    count = 0
    x = 0
    
    while (count < point1):
        if parent2[x] not in parent1_chromosomes:
            child.append(parent2[x])
            count = count + 1
        x = x + 1
    for i in range(point1,point2 + 1):
        child.append(parent1[i])
        count = count + 1
    while (count < len(parent1)):
        if parent2[x] not in child:
            child.append(parent2[x])
            count = count + 1
        x = x + 1
    
    # this is kind of a mutation but not really, it's just the chromosomes dancing
    alpha = randint(0,len(parents))
    child = child[alpha:] + child[:alpha]

    return child

def create_new_population(parents):
    children = []
    if (len(parents)%2 == 1):
        parents.pop()
        
    for i in range(0,len(parents),2):
        pair = [parents[i],parents[i+1]]
        offspring = crossover(pair)
        children.append(offspring)
    return children
    
children = create_new_population(parents)
print(children)
# Out:
# [[0, 6, 2, 7, 5, 3, 1, 4], [6, 2, 3, 7, 0, 4, 5, 1], [4, 6, 5, 7, 0, 4, 3, 1], [3, 0, 2, 7, 5, 1, 6, 4], [2, 1, 3, 0, 4, 6, 7, 5], [7, 5, 3, 0, 4, 1, 6, 2], [0, 6, 4, 7, 5, 3, 2, 6], [5, 1, 4, 0, 6, 3, 2, 7], [2, 0, 3, 5, 4, 6, 1, 7], [4, 2, 5, 1, 0, 7, 3, 6], [0, 3, 6, 2, 5, 7, 4, 1], [0, 4, 3, 1, 7, 5, 6, 2], [4, 7, 1, 3, 0, 6, 7, 2], [3, 1, 4, 6, 0, 2, 7, 3], [2, 1, 5, 6, 0, 3, 7, 7], [0, 2, 4, 7, 1, 3, 5, 6], [5, 0, 4, 1, 7, 3, 6, 2], [6, 3, 0, 1, 7, 2, 5, 4], [4, 6, 3, 0, 2, 1, 7, 2]]

# %%
# 5. Mutation

def mutate(child, parents, mutation_rate):
    val = uniform(0.0, 1.0)
    if mutation_rate > val:
        point1 = randint(0,len(parents[0])/2-1)
        point2 = randint(len(parents[0])/2,len(parents[0])-1)
        child[point1],child[point2] = child[point2],child[point1]
    return child
    
mutation_rate = 0.1

def create_mutated_children(children, parents, mutation_rate):
    return [mutate(child, parents, mutation_rate) for child in children]

print("------MUTATED CHILDREN-----")
children = create_mutated_children(children, parents, mutation_rate)
print(children)
print("---------------------------")
# Out:
# ------MUTATED CHILDREN-----
# [[0, 6, 2, 5, 7, 3, 1, 4], [6, 2, 3, 7, 0, 4, 5, 1], [4, 6, 5, 7, 0, 4, 3, 1], [3, 0, 2, 7, 5, 1, 6, 4], [2, 1, 3, 0, 4, 6, 7, 5], [7, 5, 3, 0, 4, 1, 6, 2], [0, 6, 4, 7, 5, 3, 2, 6], [5, 1, 4, 0, 6, 3, 2, 7], [2, 0, 3, 5, 4, 6, 1, 7], [4, 2, 5, 1, 0, 7, 3, 6], [0, 3, 6, 2, 5, 7, 4, 1], [0, 4, 3, 1, 7, 5, 6, 2], [4, 7, 1, 3, 0, 6, 7, 2], [3, 1, 4, 6, 0, 2, 7, 3], [2, 1, 5, 6, 0, 3, 7, 7], [0, 2, 4, 7, 1, 3, 5, 6], [5, 0, 4, 1, 7, 3, 6, 2], [6, 3, 0, 1, 7, 2, 5, 4], [4, 6, 3, 0, 2, 1, 7, 2]]
# ---------------------------

# %%
# 6. Fitness Evaluation for the new individuals: Evaluate the fitness of the new population.

fitness_scores_children_edition = evaluate_fitness(children, weights, N)
print(fitness_scores_children_edition)
# Out:
# [8, 28, 1, 32, 3, 34, 35, 21, 12, 13, 25, 9, 35, 23, 16, 35, 34, -10, 21]

# %%
# 7. Form the new population

def select_surviving(population,fitness_scores):
    survived = []
    for i in range(len(population)):
        if fitness_scores[i]<0:
            alpha = randint(fitness_scores[i], 0)
        else:  
            alpha = randint(0, fitness_scores[i])
        if alpha > fitness_scores[i]/2:
            survived.append(population[i])
    return survived

surviving = select_surviving(children, fitness_scores_children_edition)
print(surviving)
# Out:
# [[0, 6, 2, 5, 7, 3, 1, 4], [6, 2, 3, 7, 0, 4, 5, 1], [4, 6, 5, 7, 0, 4, 3, 1], [3, 0, 2, 7, 5, 1, 6, 4], [2, 1, 3, 0, 4, 6, 7, 5], [0, 6, 4, 7, 5, 3, 2, 6], [5, 1, 4, 0, 6, 3, 2, 7], [0, 3, 6, 2, 5, 7, 4, 1], [0, 4, 3, 1, 7, 5, 6, 2], [2, 1, 5, 6, 0, 3, 7, 7], [0, 2, 4, 7, 1, 3, 5, 6], [5, 0, 4, 1, 7, 3, 6, 2], [6, 3, 0, 1, 7, 2, 5, 4], [4, 6, 3, 0, 2, 1, 7, 2]]

# %%
# 8. Generations

generations = 100

for _ in range(generations):
        family = []
        
        # Fitness evaluation
        fitness_scores = evaluate_fitness(surviving, weights, N)
        
        # Selection
        parents, pos = select_parents(surviving, fitness_scores)
        family.append(parents[0])
        family.append(parents[1])
        
        # Crossover
        offspring = crossover(family)
        
        # Mutation
        mutated_offspring = mutate(offspring, parents, mutation_rate)
        family.append(mutated_offspring)
                
        # Calculate fitness for whole family
        fitness_family = evaluate_fitness(family, weights, N)
        
        # Replace the population with the new generation
        if(fitness_family[0] < fitness_family[1]) and (fitness_family[0] < fitness_family[2]):
            surviving[pos[0]] = mutated_offspring
            
        if(fitness_family[1] < fitness_family[0]) and (fitness_family[1] < fitness_family[2]):
            surviving[pos[1]] = mutated_offspring
print(surviving)
# Out:
# [[0, 6, 2, 5, 7, 3, 1, 4], [6, 2, 3, 7, 0, 4, 5, 1], [4, 6, 5, 7, 0, 4, 3, 1], [3, 0, 2, 7, 5, 1, 6, 4], [2, 1, 3, 0, 4, 6, 7, 5], [0, 6, 4, 7, 5, 3, 2, 6], [5, 1, 4, 0, 6, 3, 2, 7], [0, 3, 6, 2, 5, 7, 4, 1], [0, 4, 3, 1, 7, 5, 6, 2], [2, 1, 5, 6, 0, 3, 7, 7], [0, 2, 4, 7, 1, 3, 5, 6], [5, 0, 4, 1, 7, 3, 6, 2], [6, 3, 0, 1, 7, 2, 5, 4], [4, 6, 3, 0, 2, 1, 7, 2]]

# %%
# 9. Termination

def best_individual(final_population):
    pos = 0
    final_fitness_scores = evaluate_fitness(final_population, weights, N)
    for i in range(len(final_fitness_scores)):
        if final_fitness_scores[i] >= final_fitness_scores[pos]:
            pos = i
    return final_population[pos], final_fitness_scores[pos]

best_individ, best_fit = best_individual(surviving)
print("-------------------------------")
print("Best individual genes are:")
print(best_individ)
print("-------------------------------")
print(f"Weight: {best_fit:.0f}")
# Out:
# -------------------------------
# Best individual genes are:
# [0, 2, 4, 7, 1, 3, 5, 6]
# -------------------------------
# Weight: 35

# %%
# Credits to this paper for the theory and methods: https://arxiv.org/ftp/arxiv/papers/1802/1802.02006.pdf
# Code was written solo with the paper :P
