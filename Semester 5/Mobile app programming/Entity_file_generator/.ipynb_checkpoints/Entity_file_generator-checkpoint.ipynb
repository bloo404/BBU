# %%
list_items = ['id','name','team','details','status','participants','type']
types = [2,1,1,1,1,0,1] # 0 is int, 1 is string, 2 is int?
file = "class Entity{ \n"

for i in range(0,len(types)):
    line = ""
    if types[i]==2:
        line = 'int? '
    elif types[i]==0:
        line = 'int '
    elif types[i]==1:
        line = 'String '
    line += list_items[i] + ';'
    file+= line + '\n'

file += "Entity({"

for i in range(0, len(types)):
    if types[i]!=2:
        file += 'required '
    file += 'this.' + list_items[i]
    if i!=len(types)-1:
         file+= ',' + '\n'

file += "}); \n"

file += " factory Entity.fromJson(Map<String, dynamic> json) { \n return Entity( \n"

for i in range(0, len(types)):
    file += list_items[i] + ': json[\'' + list_items[i] + '\'] ' + 'as '
    if types[i]==2:
        file += 'int?'
    elif types[i]==1:
        file += 'String'
    elif types[i]==0:
        file += 'int'
    if i!=len(types)-1:
         file+= ',' + '\n'

file += '); \n } \n'

file += 'Map<String, dynamic> toJson() { \n return { \n '

for i in range(0, len(types)):
    file += '\'' + list_items[i] + '\':' + list_items[i]
    if i!=len(types)-1:
         file+= ',' + '\n'
            
file += '}; \n }\n Map<String, dynamic> toJsonWithoutId() { \n return { \n'

for i in range(1, len(types)):
    file += '\'' + list_items[i] + '\':' + list_items[i]
    if i!=len(types)-1:
         file+= ',' + '\n'

file += '}; \n } \n '

file += 'Entity copy({ \n'

for i in range(0, len(types)):
    line = ""
    if types[i]==2 or types[i]==0:
        line = 'int? '
    elif types[i]==1:
        line = 'String? '
    line += list_items[i]
    if i!=len(types)-1:
         line+= ','
    file+= line + '\n'
    
file += '}) => \n Entity( \n'

for i in range(0, len(types)):
    line = ""
    line += list_items[i] + ': ' + list_items[i] + ' ?? ' + 'this.' + list_items[i] 
    if i!=len(types)-1:
         line += ','
    else: line += ');'
    file+= line + '\n'

file += "@override \n String toString() { \n return \'Entity - "

for i in range(0, len(types)):
    line = ""
    line += list_items[i] + ': $' + list_items[i]
    if i!=len(types)-1:
         line += ','
    else: line += '\' ; } }'
    file+= line + ' '

    
print(file)
# Out:
# class Entity{
# int? id;
# String name;
# String team;
# String details;
# String status;
# int participants;
# String type;
# Entity({this.id,
# required this.name,
# required this.team,
# required this.details,
# required this.status,
# required this.participants,
# required this.type});
#  factory Entity.fromJson(Map<String, dynamic> json) {
#  return Entity(
# id: json['id'] as int?,
# name: json['name'] as String,
# team: json['team'] as String,
# details: json['details'] as String,
# status: json['status'] as String,
# participants: json['participants'] as int,
# type: json['type'] as String);
#  }
# Map<String, dynamic> toJson() {
#  return {
#  'id':id,
# 'name':name,
# 'team':team,
# 'details':details,
# 'status':status,
# 'participants':participants,
# 'type':type};
#  }
#  Map<String, dynamic> toJsonWithoutId() {
#  return {
# 'name':name,
# 'team':team,
# 'details':details,
# 'status':status,
# 'participants':participants,
# 'type':type};
#  }
#  Entity copy({
# int? id,
# String? name,
# String? team,
# String? details,
# String? status,
# int? participants,
# String? type
# }) =>
#  Entity(
# id: id ?? this.id,
# name: name ?? this.name,
# team: team ?? this.team,
# details: details ?? this.details,
# status: status ?? this.status,
# participants: participants ?? this.participants,
# type: type ?? this.type);
# @override
#  String toString() {
#  return 'Entity - id: $id, name: $name, team: $team, details: $details, status: $status, participants: $participants, type: $type' ; } }
