# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, Normalizer, KBinsDiscretizer, OneHotEncoder
import warnings
from sklearn.decomposition import PCA

# %%
datapath = r'C:\Users\bloo404\Desktop\3\SEM 2\MIASC\QORn_Assignment02\Dataset_partial'

column_names = ["Momentul masurarii" , "UID", 'what measures', 'valoare', 'prag pornire', 'prag oprire', 'alarma']
radon_df = pd.DataFrame()
co2_df = pd.DataFrame()

for filename in os.listdir(datapath):
    file_path = os.path.join(datapath, filename)
    df = pd.read_csv(file_path, header=None)
    df = df.iloc[:, :7] 
    df.columns = column_names[:len(df.columns)] 
    if "RADON" in filename.upper():
        radon_df = pd.concat([radon_df, df], ignore_index=True)
    else:
        co2_df = pd.concat([co2_df, df], ignore_index=True)

display(radon_df)
display(co2_df)
# Out:
#                  Momentul masurarii              UID what measures  valoare  \
# 0        2019-01-01 00:00:21.899000  000.021.174.106         RADON      151
# 1        2019-01-01 00:00:23.560000  000.021.160.006         RADON      689
# 2        2019-01-01 00:00:35.229000  000.021.182.192         RADON      171
# 3        2019-01-01 00:00:37.225000  000.022.011.031         RADON      878
# 4        2019-01-01 00:00:39.669000  000.021.251.221         RADON      253
# ...                             ...              ...           ...      ...
# 3654637  2019-02-28 23:59:02.050000  000.021.251.248         RADON      509
# 3654638  2019-02-28 23:59:04.694000  000.021.250.156         RADON      334
# 3654639  2019-02-28 23:59:08.630000  000.021.194.023         RADON      109
# 3654640  2019-02-28 23:59:32.882000  000.021.211.233         RADON      396
# 3654641  2019-02-28 23:59:44.979000  000.022.005.033         RADON      148
#
#          prag pornire  prag oprire  alarma
# 0                 170          300     100
# 1                 686          339     129
# 2                  18          300     100
# 3                 678          300     100
# 4                 122          300     100
# ...               ...          ...     ...
# 3654637           384          300     100
# 3654638           466          300     100
# 3654639           178          384     144
# 3654640           464          335      88
# 3654641           201          300     100
#
# [3654642 rows x 7 columns]
#                  Momentul masurarii              UID what measures  valoare  \
# 0        2019-01-01 00:00:01.964000  000.021.205.082           CO2     1743
# 1        2019-01-01 00:00:04.343000  000.022.008.098           CO2     1361
# 2        2019-01-01 00:00:12.175000  000.021.233.134           CO2      460
# 3        2019-01-01 00:00:17.444000  000.021.247.081           CO2      802
# 4        2019-01-01 00:00:18.815000  000.021.183.104           CO2      572
# ...                             ...              ...           ...      ...
# 3652809  2019-02-28 23:59:27.600000  000.021.161.206           CO2     1856
# 3652810  2019-02-28 23:59:30.674000  000.021.218.042           CO2      654
# 3652811  2019-02-28 23:59:36.927000  000.021.219.099           CO2     1640
# 3652812  2019-02-28 23:59:41.199000  000.021.184.036           CO2     1013
# 3652813  2019-02-28 23:59:57.189000  000.021.199.115           CO2      704
#
#          prag pornire  prag oprire alarma
# 0                2073          759     EN
# 1                2000         1000     DI
# 2                2000         1660     DI
# 3                4475         1097     EN
# 4                2000         1000     DI
# ...               ...          ...    ...
# 3652809          2000         1000     DI
# 3652810          2000         1000     DI
# 3652811          2000         1000     DI
# 3652812          2000         1000     DI
# 3652813          2000         1000     DI
#
# [3652814 rows x 7 columns]

# %%
union_df = pd.concat([radon_df, co2_df], axis=0)
union_df.reset_index(drop=True, inplace=True)
display(union_df)
# Out:
#                  Momentul masurarii              UID what measures  valoare  \
# 0        2019-01-01 00:00:21.899000  000.021.174.106         RADON      151
# 1        2019-01-01 00:00:23.560000  000.021.160.006         RADON      689
# 2        2019-01-01 00:00:35.229000  000.021.182.192         RADON      171
# 3        2019-01-01 00:00:37.225000  000.022.011.031         RADON      878
# 4        2019-01-01 00:00:39.669000  000.021.251.221         RADON      253
# ...                             ...              ...           ...      ...
# 7307451  2019-02-28 23:59:27.600000  000.021.161.206           CO2     1856
# 7307452  2019-02-28 23:59:30.674000  000.021.218.042           CO2      654
# 7307453  2019-02-28 23:59:36.927000  000.021.219.099           CO2     1640
# 7307454  2019-02-28 23:59:41.199000  000.021.184.036           CO2     1013
# 7307455  2019-02-28 23:59:57.189000  000.021.199.115           CO2      704
#
#          prag pornire  prag oprire alarma
# 0                 170          300    100
# 1                 686          339    129
# 2                  18          300    100
# 3                 678          300    100
# 4                 122          300    100
# ...               ...          ...    ...
# 7307451          2000         1000     DI
# 7307452          2000         1000     DI
# 7307453          2000         1000     DI
# 7307454          2000         1000     DI
# 7307455          2000         1000     DI
#
# [7307456 rows x 7 columns]

# %%
description = union_df.describe()
print(description)
# Out:
#             valoare  prag pornire   prag oprire
# count  7.307456e+06  7.307456e+06  7.307456e+06
# mean   8.244375e+02  1.351951e+03  6.992548e+02
# std    6.955164e+02  1.023364e+03  5.331242e+02
# min    0.000000e+00  0.000000e+00  1.210000e+02
# 25%    3.730000e+02  3.980000e+02  3.000000e+02
# 50%    6.360000e+02  1.294000e+03  5.000000e+02
# 75%    1.044000e+03  2.000000e+03  1.000000e+03
# max    4.479000e+03  5.000000e+03  4.738000e+03

# %%
head = union_df.head(10000)
tail = union_df.tail(10000)
union_df = pd.concat([head, tail], ignore_index=True)
display(union_df)
# Out:
#                Momentul masurarii              UID what measures  valoare  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106         RADON      151
# 1      2019-01-01 00:00:23.560000  000.021.160.006         RADON      689
# 2      2019-01-01 00:00:35.229000  000.021.182.192         RADON      171
# 3      2019-01-01 00:00:37.225000  000.022.011.031         RADON      878
# 4      2019-01-01 00:00:39.669000  000.021.251.221         RADON      253
# ...                           ...              ...           ...      ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206           CO2     1856
# 19996  2019-02-28 23:59:30.674000  000.021.218.042           CO2      654
# 19997  2019-02-28 23:59:36.927000  000.021.219.099           CO2     1640
# 19998  2019-02-28 23:59:41.199000  000.021.184.036           CO2     1013
# 19999  2019-02-28 23:59:57.189000  000.021.199.115           CO2      704
#
#        prag pornire  prag oprire alarma
# 0               170          300    100
# 1               686          339    129
# 2                18          300    100
# 3               678          300    100
# 4               122          300    100
# ...             ...          ...    ...
# 19995          2000         1000     DI
# 19996          2000         1000     DI
# 19997          2000         1000     DI
# 19998          2000         1000     DI
# 19999          2000         1000     DI
#
# [20000 rows x 7 columns]

# %%
numeric_columns = union_df.select_dtypes(include=['number']).columns
union_df[numeric_columns] = union_df[numeric_columns].fillna(union_df[numeric_columns].mean())

# %%
display(union_df)
# Out:
#                Momentul masurarii              UID what measures  valoare  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106         RADON      151
# 1      2019-01-01 00:00:23.560000  000.021.160.006         RADON      689
# 2      2019-01-01 00:00:35.229000  000.021.182.192         RADON      171
# 3      2019-01-01 00:00:37.225000  000.022.011.031         RADON      878
# 4      2019-01-01 00:00:39.669000  000.021.251.221         RADON      253
# ...                           ...              ...           ...      ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206           CO2     1856
# 19996  2019-02-28 23:59:30.674000  000.021.218.042           CO2      654
# 19997  2019-02-28 23:59:36.927000  000.021.219.099           CO2     1640
# 19998  2019-02-28 23:59:41.199000  000.021.184.036           CO2     1013
# 19999  2019-02-28 23:59:57.189000  000.021.199.115           CO2      704
#
#        prag pornire  prag oprire alarma
# 0               170          300    100
# 1               686          339    129
# 2                18          300    100
# 3               678          300    100
# 4               122          300    100
# ...             ...          ...    ...
# 19995          2000         1000     DI
# 19996          2000         1000     DI
# 19997          2000         1000     DI
# 19998          2000         1000     DI
# 19999          2000         1000     DI
#
# [20000 rows x 7 columns]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(union_df['what measures'], union_df['valoare'], alpha=0.5)
plt.xlabel('What measures')
plt.ylabel('valoare')
plt.title('Scatter Plot of What measures vs. valoare')
plt.grid(True)
plt.show()

# %%
selected_columns = ["what measures", "valoare"]

selected_df = union_df[selected_columns]

for measure, group_df in selected_df.groupby("what measures"):
    plt.figure(figsize=(8, 6))
    plt.hist(group_df["valoare"], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of valoare for {measure}')
    plt.xlabel("valoare")
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
numeric_columns = union_df.select_dtypes(include=['number']).columns

scaler = StandardScaler()

union_df[numeric_columns] = scaler.fit_transform(union_df[numeric_columns])

print(union_df)
# Out:
#                Momentul masurarii              UID what measures   valoare  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106         RADON -0.969254
# 1      2019-01-01 00:00:23.560000  000.021.160.006         RADON -0.189283
# 2      2019-01-01 00:00:35.229000  000.021.182.192         RADON -0.940259
# 3      2019-01-01 00:00:37.225000  000.022.011.031         RADON  0.084722
# 4      2019-01-01 00:00:39.669000  000.021.251.221         RADON -0.821379
# ...                           ...              ...           ...       ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206           CO2  1.502589
# 19996  2019-02-28 23:59:30.674000  000.021.218.042           CO2 -0.240025
# 19997  2019-02-28 23:59:36.927000  000.021.219.099           CO2  1.189440
# 19998  2019-02-28 23:59:41.199000  000.021.184.036           CO2  0.280440
# 19999  2019-02-28 23:59:57.189000  000.021.199.115           CO2 -0.167536
#
#        prag pornire  prag oprire alarma
# 0         -1.148531    -0.686057    100
# 1         -0.648580    -0.622792    129
# 2         -1.295804    -0.686057    100
# 3         -0.656331    -0.686057    100
# 4         -1.195038    -0.686057    100
# ...             ...          ...    ...
# 19995      0.624552     0.449472     DI
# 19996      0.624552     0.449472     DI
# 19997      0.624552     0.449472     DI
# 19998      0.624552     0.449472     DI
# 19999      0.624552     0.449472     DI
#
# [20000 rows x 7 columns]

# %%
warnings.filterwarnings("ignore", category=UserWarning)

normalizer_L1 = Normalizer(norm='l1')

union_df_L1 = union_df.copy()
union_df_L1[numeric_columns] = normalizer_L1.transform(union_df_L1[numeric_columns])

union_df_L1.columns = union_df.columns

print("Normalized with L1:")
print(union_df_L1.head())
# Out:
# Normalized with L1:
#            Momentul masurarii              UID what measures   valoare  \
# 0  2019-01-01 00:00:21.899000  000.021.174.106         RADON -0.345688
# 1  2019-01-01 00:00:23.560000  000.021.160.006         RADON -0.129588
# 2  2019-01-01 00:00:35.229000  000.021.182.192         RADON -0.321773
# 3  2019-01-01 00:00:37.225000  000.022.011.031         RADON  0.059366
# 4  2019-01-01 00:00:39.669000  000.021.251.221         RADON -0.303936
#
#    prag pornire  prag oprire alarma
# 0     -0.409628    -0.244685    100
# 1     -0.444034    -0.426379    129
# 2     -0.443446    -0.234781    100
# 3     -0.459902    -0.480732    100
# 4     -0.442202    -0.253863    100

# %%
discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')

union_df_L1[numeric_columns] = discretizer.fit_transform(union_df_L1[numeric_columns])

print(union_df_L1)
# Out:
#                Momentul masurarii              UID what measures  valoare  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106         RADON      1.0
# 1      2019-01-01 00:00:23.560000  000.021.160.006         RADON      2.0
# 2      2019-01-01 00:00:35.229000  000.021.182.192         RADON      1.0
# 3      2019-01-01 00:00:37.225000  000.022.011.031         RADON      4.0
# 4      2019-01-01 00:00:39.669000  000.021.251.221         RADON      1.0
# ...                           ...              ...           ...      ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206           CO2      8.0
# 19996  2019-02-28 23:59:30.674000  000.021.218.042           CO2      2.0
# 19997  2019-02-28 23:59:36.927000  000.021.219.099           CO2      7.0
# 19998  2019-02-28 23:59:41.199000  000.021.184.036           CO2      5.0
# 19999  2019-02-28 23:59:57.189000  000.021.199.115           CO2      2.0
#
#        prag pornire  prag oprire alarma
# 0               1.0          2.0    100
# 1               1.0          1.0    129
# 2               1.0          2.0    100
# 3               1.0          0.0    100
# 4               1.0          2.0    100
# ...             ...          ...    ...
# 19995           6.0          5.0     DI
# 19996           7.0          6.0     DI
# 19997           6.0          5.0     DI
# 19998           7.0          6.0     DI
# 19999           7.0          6.0     DI
#
# [20000 rows x 7 columns]

# %%
onehot_encoder = OneHotEncoder(sparse=False)
onehot_encoded = onehot_encoder.fit_transform(union_df_L1[['what measures']])
onehot_encoded_df = pd.DataFrame(onehot_encoded, columns=onehot_encoder.get_feature_names(['what measures']))

union_df_encoded = pd.concat([union_df_L1.drop(columns=['what measures']), onehot_encoded_df], axis=1)

print(union_df_encoded)
# Out:
#                Momentul masurarii              UID  valoare  prag pornire  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106      1.0           1.0
# 1      2019-01-01 00:00:23.560000  000.021.160.006      2.0           1.0
# 2      2019-01-01 00:00:35.229000  000.021.182.192      1.0           1.0
# 3      2019-01-01 00:00:37.225000  000.022.011.031      4.0           1.0
# 4      2019-01-01 00:00:39.669000  000.021.251.221      1.0           1.0
# ...                           ...              ...      ...           ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206      8.0           6.0
# 19996  2019-02-28 23:59:30.674000  000.021.218.042      2.0           7.0
# 19997  2019-02-28 23:59:36.927000  000.021.219.099      7.0           6.0
# 19998  2019-02-28 23:59:41.199000  000.021.184.036      5.0           7.0
# 19999  2019-02-28 23:59:57.189000  000.021.199.115      2.0           7.0
#
#        prag oprire alarma  what measures_CO2  what measures_RADON
# 0              2.0    100                0.0                  1.0
# 1              1.0    129                0.0                  1.0
# 2              2.0    100                0.0                  1.0
# 3              0.0    100                0.0                  1.0
# 4              2.0    100                0.0                  1.0
# ...            ...    ...                ...                  ...
# 19995          5.0     DI                1.0                  0.0
# 19996          6.0     DI                1.0                  0.0
# 19997          5.0     DI                1.0                  0.0
# 19998          6.0     DI                1.0                  0.0
# 19999          6.0     DI                1.0                  0.0
#
# [20000 rows x 8 columns]
# C:\Users\bloo404\anaconda3\envs\AIClimate\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
selected_features = union_df_encoded[['Momentul masurarii', 'UID', 'valoare', 'what measures_CO2', 'what measures_RADON']]
display(selected_features)
# Out:
#                Momentul masurarii              UID  valoare  \
# 0      2019-01-01 00:00:21.899000  000.021.174.106      1.0
# 1      2019-01-01 00:00:23.560000  000.021.160.006      2.0
# 2      2019-01-01 00:00:35.229000  000.021.182.192      1.0
# 3      2019-01-01 00:00:37.225000  000.022.011.031      4.0
# 4      2019-01-01 00:00:39.669000  000.021.251.221      1.0
# ...                           ...              ...      ...
# 19995  2019-02-28 23:59:27.600000  000.021.161.206      8.0
# 19996  2019-02-28 23:59:30.674000  000.021.218.042      2.0
# 19997  2019-02-28 23:59:36.927000  000.021.219.099      7.0
# 19998  2019-02-28 23:59:41.199000  000.021.184.036      5.0
# 19999  2019-02-28 23:59:57.189000  000.021.199.115      2.0
#
#        what measures_CO2  what measures_RADON
# 0                    0.0                  1.0
# 1                    0.0                  1.0
# 2                    0.0                  1.0
# 3                    0.0                  1.0
# 4                    0.0                  1.0
# ...                  ...                  ...
# 19995                1.0                  0.0
# 19996                1.0                  0.0
# 19997                1.0                  0.0
# 19998                1.0                  0.0
# 19999                1.0                  0.0
#
# [20000 rows x 5 columns]

# %%
selected_features['Momentul masurarii'] = pd.to_datetime(selected_features['Momentul masurarii'])
display(selected_features)
# Out:
# C:\Users\bloo404\AppData\Local\Temp\ipykernel_30404\1373533976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_features['Momentul masurarii'] = pd.to_datetime(selected_features['Momentul masurarii'])
#            Momentul masurarii              UID  valoare  what measures_CO2  \
# 0     2019-01-01 00:00:21.899  000.021.174.106      1.0                0.0
# 1     2019-01-01 00:00:23.560  000.021.160.006      2.0                0.0
# 2     2019-01-01 00:00:35.229  000.021.182.192      1.0                0.0
# 3     2019-01-01 00:00:37.225  000.022.011.031      4.0                0.0
# 4     2019-01-01 00:00:39.669  000.021.251.221      1.0                0.0
# ...                       ...              ...      ...                ...
# 19995 2019-02-28 23:59:27.600  000.021.161.206      8.0                1.0
# 19996 2019-02-28 23:59:30.674  000.021.218.042      2.0                1.0
# 19997 2019-02-28 23:59:36.927  000.021.219.099      7.0                1.0
# 19998 2019-02-28 23:59:41.199  000.021.184.036      5.0                1.0
# 19999 2019-02-28 23:59:57.189  000.021.199.115      2.0                1.0
#
#        what measures_RADON
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# ...                    ...
# 19995                  0.0
# 19996                  0.0
# 19997                  0.0
# 19998                  0.0
# 19999                  0.0
#
# [20000 rows x 5 columns]

# %%
# These are not appliable to us

selected_features_numeric = selected_features.select_dtypes(include=['number'])

scaler = StandardScaler()
selected_features_scaled = scaler.fit_transform(selected_features_numeric)

display(selected_features_scaled)
# Out:
# array([[-0.84110642, -1.        ,  1.        ],
#        [-0.44801093, -1.        ,  1.        ],
#        [-0.84110642, -1.        ,  1.        ],
#        ...,
#        [ 1.51746652,  1.        , -1.        ],
#        [ 0.73127554,  1.        , -1.        ],
#        [-0.44801093,  1.        , -1.        ]])

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(selected_features_scaled)

principal_df = pd.DataFrame(data=principal_components, columns=['Principal Component 1', 'Principal Component 2'])

print(principal_df)

plt.figure(figsize=(8, 6))
plt.scatter(principal_df['Principal Component 1'], principal_df['Principal Component 2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Principal Components')
plt.show()
# Out:
#        Principal Component 1  Principal Component 2
# 0                  -1.643977              -0.069290
# 1                  -1.457441               0.276728
# 2                  -1.643977              -0.069290
# 3                  -1.084371               0.968765
# 4                  -1.643977              -0.069290
# ...                      ...                    ...
# 19995               2.151464               1.010668
# 19996               1.032253              -1.065442
# 19997               1.964929               0.664650
# 19998               1.591859              -0.027387
# 19999               1.032253              -1.065442
#
# [20000 rows x 2 columns]
